# %%
import pandas as pd
import time
from datetime import datetime
import cv2
import numpy as np
import os
import youtube_dl

# %%
def get_sec(time_str):
    """Get Seconds from time."""
    h, m, s = time_str.split(':')
    return int(h) * 3600 + int(m) * 60 + int(s)

def listdir_nohidden(directory):
    filelist = os.listdir(directory)
    return [x for x in filelist
            if not (x.startswith('.'))]

# %%
classifier_directory = os.getcwd()
parent_directory = classifier_directory[:-11] #exclude '/classifier'

pathway_to_clips = classifier_directory + '/movie_clips'
pathway_to_frames = classifier_directory + '/frames'

# %%
df  = pd.read_csv(classifier_directory + '/twostepper_input.csv')
url_unique_vals = df.URL.unique()
title_unique_vals = df.Title.unique()

# [df['URL'].str.contains(url_unique_vals[0])]
# df[df['Title'].str.match(title_unique_vals[0])]

try:
    if not os.path.exists(classifier_directory + '/youtube_videos'):
        os.makedirs(classifier_directory + '/youtube_videos')
    if not os.path.exists(classifier_directory + '/movie_clips'):
        os.makedirs(classifier_directory + '/movie_clips')
    if not os.path.exists(classifier_directory + '/frames'):
        os.makedirs(classifier_directory + '/frames')        
except OSError:
    print ('Error: Creating directory of data')

os.chdir(classifier_directory + '/youtube_videos')

for kk in range(len(title_unique_vals)):
    url_lookup = url_unique_vals[kk]
    title = title_unique_vals[kk]
    dfsub = df[df['Title'].str.match(title_unique_vals[kk])]
    dfsub = dfsub.reset_index()


    
    # !youtube-dl -f 'bestvideo[height<=480, ext=mp4]' $url_lookup --id    

    
    for jj in range(len(dfsub)):
        start_time = get_sec(dfsub.start_time[jj])
        end_time = get_sec(dfsub.end_time[jj])
        
        #augmenter
        early_start_time = start_time - (0.5 * (end_time - start_time))
        late_end_time = end_time + (0.5 * (end_time - start_time))
        late_start_time = start_time + (0.25 * (end_time - start_time))
        early_end_time = end_time - (0.25 * (end_time - start_time))
        
        movie_name = dfsub.URL[jj][-11:] + '.mp4'
        movie_out_clip = dfsub.move[jj] + '.' + dfsub.URL[jj][-11:] + '__' + str(start_time) + '__' + str(end_time) + '.mov'
        movie_out_clip_long = dfsub.move[jj] + '.' + dfsub.URL[jj][-11:] + '__' + str(early_start_time) + '__' + str(late_end_time) + '.mov'
#         movie_out_clip_short = dfsub.move[jj] + '.' + dfsub.URL[jj][-11:] + '__' + str(late_start_time) + '__' + str(early_end_time) + '.mov'
        movie_out_clip_early = dfsub.move[jj] + '.' + dfsub.URL[jj][-11:] + '__' + str(early_start_time) + '__' + str(early_end_time) + '.mov'
        movie_out_clip_late = dfsub.move[jj] + '.' + dfsub.URL[jj][-11:] + '__' + str(late_start_time) + '__' + str(late_end_time) + '.mov'
        
        movie_out_name_and_path = classifier_directory + '/movie_clips/' + movie_out_clip
        movie_out_name_and_path_long = classifier_directory + '/movie_clips/' + movie_out_clip_long 
#         movie_out_name_and_path_short = classifier_directory + '/movie_clips/' + movie_out_clip_short
        movie_out_name_and_path_early = classifier_directory + '/movie_clips/' + movie_out_clip_early 
        movie_out_name_and_path_late = classifier_directory + '/movie_clips/' + movie_out_clip_late

        #original 
        # !ffmpeg -ss $start_time -to $end_time -i $movie_name -c copy $movie_out_name_and_path 
        #augmented
        # !ffmpeg -ss $early_start_time -to $early_end_time -i $movie_name -c copy $movie_out_name_and_path_early 
        # !ffmpeg -ss $early_start_time -to $late_end_time -i $movie_name -c copy $movie_out_name_and_path_long
        # !ffmpeg -ss $late_start_time -to $late_end_time -i $movie_name -c copy $movie_out_name_and_path_late

#         !ffmpeg -ss $late_start_time -to $early_end_time -i $movie_name -c copy $movie_out_name_and_path_short 


    
    

os.chdir(pathway_to_clips)
clip_names = listdir_nohidden(pathway_to_clips)


for ii in range(len(clip_names)):
    clip_name = clip_names[ii]
    vidcap = cv2.VideoCapture(pathway_to_clips + '/' + clip_names[ii])
    success,image = vidcap.read()
        
    frame_dir = pathway_to_frames + '/' + clip_name[:-4]
    
    try:
        if not os.path.exists(frame_dir):
            os.makedirs(frame_dir)
    except OSError:
        print ('Error: Creating directory of data')


    est_tot_frames = vidcap.get(cv2.CAP_PROP_FRAME_COUNT)  # Sets an upper bound # of frames in video clip
    desired_frames = np.round(np.arange(0,est_tot_frames,est_tot_frames/30)) #split the video into 30 frames

    for i in desired_frames:
        vidcap.set(1,i-1)                      
        success,image = vidcap.read(1)         # image is an array of array of [R,G,B] values
        frameId = vidcap.get(1)                # The 0th frame is often a throw-away
        cv2.imwrite(frame_dir + '/' + clip_name + 'frame%d.jpg' % frameId, image)
    vidcap.release()
    cv2.destroyAllWindows()
# Out:
# [youtube] qxqu7p8oK5g: Downloading webpage
# [youtube] qxqu7p8oK5g: Downloading video info webpage
# [download] Destination: qxqu7p8oK5g.mp4
# [download] 100% of 51.53MiB in 00:0495MiB/s ETA 00:0032
# ffmpeg version 4.0.2 Copyright (c) 2000-2018 the FFmpeg developers
#   built with Apple LLVM version 6.1.0 (clang-602.0.53) (based on LLVM 3.6.0svn)
#   configuration: --prefix=/anaconda3 --disable-doc --disable-openssl --enable-shared --enable-static --extra-cflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-cxxflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-libs='-lpthread -lm -lz' --enable-zlib --enable-pic --enable-pthreads --enable-gpl --enable-version3 --enable-hardcoded-tables --enable-avresample --enable-libfreetype --enable-gnutls --enable-libx264 --enable-libopenh264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'qxqu7p8oK5g.mp4':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     creation_time   : 2019-12-10T13:01:51.000000Z
#   Duration: 00:05:41.37, start: 0.000000, bitrate: 1266 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], 39 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2019-12-10T13:01:51.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
# Output #0, mov, to '/Users/max/Documents/Insight/TwoStepper/classifier/movie_clips/turn.qxqu7p8oK5g__16__21.mov':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     encoder         : Lavf58.12.100
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 39 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 30k tbc (default)
#     Metadata:
#       creation_time   : 2019-12-10T13:01:51.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# frame=  311 fps=0.0 q=-1.0 Lsize=    1763kB time=00:00:04.98 bitrate=2896.1kbits/s speed=1.92e+03x
# video:1760kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.194105%
# ffmpeg version 4.0.2 Copyright (c) 2000-2018 the FFmpeg developers
#   built with Apple LLVM version 6.1.0 (clang-602.0.53) (based on LLVM 3.6.0svn)
#   configuration: --prefix=/anaconda3 --disable-doc --disable-openssl --enable-shared --enable-static --extra-cflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-cxxflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-libs='-lpthread -lm -lz' --enable-zlib --enable-pic --enable-pthreads --enable-gpl --enable-version3 --enable-hardcoded-tables --enable-avresample --enable-libfreetype --enable-gnutls --enable-libx264 --enable-libopenh264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'qxqu7p8oK5g.mp4':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     creation_time   : 2019-12-10T13:01:51.000000Z
#   Duration: 00:05:41.37, start: 0.000000, bitrate: 1266 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], 39 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2019-12-10T13:01:51.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
# Output #0, mov, to '/Users/max/Documents/Insight/TwoStepper/classifier/movie_clips/turn.qxqu7p8oK5g__13.5__19.75.mov':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     encoder         : Lavf58.12.100
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 39 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 30k tbc (default)
#     Metadata:
#       creation_time   : 2019-12-10T13:01:51.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# frame=  273 fps=0.0 q=-1.0 Lsize=    1523kB time=00:00:06.21 bitrate=2005.9kbits/s speed=2.78e+03x
# video:1520kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.202138%
# ffmpeg version 4.0.2 Copyright (c) 2000-2018 the FFmpeg developers
#   built with Apple LLVM version 6.1.0 (clang-602.0.53) (based on LLVM 3.6.0svn)
#   configuration: --prefix=/anaconda3 --disable-doc --disable-openssl --enable-shared --enable-static --extra-cflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-cxxflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-libs='-lpthread -lm -lz' --enable-zlib --enable-pic --enable-pthreads --enable-gpl --enable-version3 --enable-hardcoded-tables --enable-avresample --enable-libfreetype --enable-gnutls --enable-libx264 --enable-libopenh264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'qxqu7p8oK5g.mp4':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     creation_time   : 2019-12-10T13:01:51.000000Z
#   Duration: 00:05:41.37, start: 0.000000, bitrate: 1266 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], 39 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2019-12-10T13:01:51.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
# Output #0, mov, to '/Users/max/Documents/Insight/TwoStepper/classifier/movie_clips/turn.qxqu7p8oK5g__13.5__23.5.mov':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     encoder         : Lavf58.12.100
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 39 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 30k tbc (default)
#     Metadata:
#       creation_time   : 2019-12-10T13:01:51.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# frame=  386 fps=0.0 q=-1.0 Lsize=    2153kB time=00:00:09.99 bitrate=1765.6kbits/s speed=3.28e+03x
# video:2149kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.189124%
# ffmpeg version 4.0.2 Copyright (c) 2000-2018 the FFmpeg developers
#   built with Apple LLVM version 6.1.0 (clang-602.0.53) (based on LLVM 3.6.0svn)
#   configuration: --prefix=/anaconda3 --disable-doc --disable-openssl --enable-shared --enable-static --extra-cflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-cxxflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-libs='-lpthread -lm -lz' --enable-zlib --enable-pic --enable-pthreads --enable-gpl --enable-version3 --enable-hardcoded-tables --enable-avresample --enable-libfreetype --enable-gnutls --enable-libx264 --enable-libopenh264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'qxqu7p8oK5g.mp4':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     creation_time   : 2019-12-10T13:01:51.000000Z
#   Duration: 00:05:41.37, start: 0.000000, bitrate: 1266 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], 39 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2019-12-10T13:01:51.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
# Output #0, mov, to '/Users/max/Documents/Insight/TwoStepper/classifier/movie_clips/turn.qxqu7p8oK5g__17.25__23.5.mov':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     encoder         : Lavf58.12.100
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 39 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 30k tbc (default)
#     Metadata:
#       creation_time   : 2019-12-10T13:01:51.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# frame=  226 fps=0.0 q=-1.0 Lsize=    1376kB time=00:00:06.24 bitrate=1806.9kbits/s speed=2.92e+03x
# video:1373kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.209749%
# ffmpeg version 4.0.2 Copyright (c) 2000-2018 the FFmpeg developers
#   built with Apple LLVM version 6.1.0 (clang-602.0.53) (based on LLVM 3.6.0svn)
#   configuration: --prefix=/anaconda3 --disable-doc --disable-openssl --enable-shared --enable-static --extra-cflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-cxxflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-libs='-lpthread -lm -lz' --enable-zlib --enable-pic --enable-pthreads --enable-gpl --enable-version3 --enable-hardcoded-tables --enable-avresample --enable-libfreetype --enable-gnutls --enable-libx264 --enable-libopenh264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'qxqu7p8oK5g.mp4':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     creation_time   : 2019-12-10T13:01:51.000000Z
#   Duration: 00:05:41.37, start: 0.000000, bitrate: 1266 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], 39 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2019-12-10T13:01:51.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
# Output #0, mov, to '/Users/max/Documents/Insight/TwoStepper/classifier/movie_clips/turn.qxqu7p8oK5g__28__33.mov':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     encoder         : Lavf58.12.100
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 39 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 30k tbc (default)
#     Metadata:
#       creation_time   : 2019-12-10T13:01:51.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# frame=  191 fps=0.0 q=-1.0 Lsize=    1298kB time=00:00:04.99 bitrate=2127.4kbits/s speed=2.57e+03x
# video:1296kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.203336%
# ffmpeg version 4.0.2 Copyright (c) 2000-2018 the FFmpeg developers
#   built with Apple LLVM version 6.1.0 (clang-602.0.53) (based on LLVM 3.6.0svn)
#   configuration: --prefix=/anaconda3 --disable-doc --disable-openssl --enable-shared --enable-static --extra-cflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-cxxflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-libs='-lpthread -lm -lz' --enable-zlib --enable-pic --enable-pthreads --enable-gpl --enable-version3 --enable-hardcoded-tables --enable-avresample --enable-libfreetype --enable-gnutls --enable-libx264 --enable-libopenh264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'qxqu7p8oK5g.mp4':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     creation_time   : 2019-12-10T13:01:51.000000Z
#   Duration: 00:05:41.37, start: 0.000000, bitrate: 1266 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], 39 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2019-12-10T13:01:51.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
# Output #0, mov, to '/Users/max/Documents/Insight/TwoStepper/classifier/movie_clips/turn.qxqu7p8oK5g__25.5__31.75.mov':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     encoder         : Lavf58.12.100
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 39 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 30k tbc (default)
#     Metadata:
#       creation_time   : 2019-12-10T13:01:51.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# frame=  313 fps=0.0 q=-1.0 Lsize=    1733kB time=00:00:06.23 bitrate=2278.2kbits/s speed=2.28e+03x
# video:1729kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.211986%
# ffmpeg version 4.0.2 Copyright (c) 2000-2018 the FFmpeg developers
#   built with Apple LLVM version 6.1.0 (clang-602.0.53) (based on LLVM 3.6.0svn)
#   configuration: --prefix=/anaconda3 --disable-doc --disable-openssl --enable-shared --enable-static --extra-cflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-cxxflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-libs='-lpthread -lm -lz' --enable-zlib --enable-pic --enable-pthreads --enable-gpl --enable-version3 --enable-hardcoded-tables --enable-avresample --enable-libfreetype --enable-gnutls --enable-libx264 --enable-libopenh264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'qxqu7p8oK5g.mp4':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     creation_time   : 2019-12-10T13:01:51.000000Z
#   Duration: 00:05:41.37, start: 0.000000, bitrate: 1266 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], 39 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2019-12-10T13:01:51.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
# Output #0, mov, to '/Users/max/Documents/Insight/TwoStepper/classifier/movie_clips/turn.qxqu7p8oK5g__25.5__35.5.mov':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     encoder         : Lavf58.12.100
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 39 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 30k tbc (default)
#     Metadata:
#       creation_time   : 2019-12-10T13:01:51.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# frame=  425 fps=0.0 q=-1.0 Lsize=    2343kB time=00:00:09.96 bitrate=1925.2kbits/s speed=2.85e+03x
# video:2338kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.196714%
# ffmpeg version 4.0.2 Copyright (c) 2000-2018 the FFmpeg developers
#   built with Apple LLVM version 6.1.0 (clang-602.0.53) (based on LLVM 3.6.0svn)
#   configuration: --prefix=/anaconda3 --disable-doc --disable-openssl --enable-shared --enable-static --extra-cflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-cxxflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-libs='-lpthread -lm -lz' --enable-zlib --enable-pic --enable-pthreads --enable-gpl --enable-version3 --enable-hardcoded-tables --enable-avresample --enable-libfreetype --enable-gnutls --enable-libx264 --enable-libopenh264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'qxqu7p8oK5g.mp4':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     creation_time   : 2019-12-10T13:01:51.000000Z
#   Duration: 00:05:41.37, start: 0.000000, bitrate: 1266 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], 39 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2019-12-10T13:01:51.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
# Output #0, mov, to '/Users/max/Documents/Insight/TwoStepper/classifier/movie_clips/turn.qxqu7p8oK5g__29.25__35.5.mov':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     encoder         : Lavf58.12.100
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 39 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 30k tbc (default)
#     Metadata:
#       creation_time   : 2019-12-10T13:01:51.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# frame=  265 fps=0.0 q=-1.0 Lsize=    1649kB time=00:00:06.21 bitrate=2172.5kbits/s speed=2.48e+03x
# video:1646kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.195196%
# ffmpeg version 4.0.2 Copyright (c) 2000-2018 the FFmpeg developers
#   built with Apple LLVM version 6.1.0 (clang-602.0.53) (based on LLVM 3.6.0svn)
#   configuration: --prefix=/anaconda3 --disable-doc --disable-openssl --enable-shared --enable-static --extra-cflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-cxxflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-libs='-lpthread -lm -lz' --enable-zlib --enable-pic --enable-pthreads --enable-gpl --enable-version3 --enable-hardcoded-tables --enable-avresample --enable-libfreetype --enable-gnutls --enable-libx264 --enable-libopenh264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'qxqu7p8oK5g.mp4':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     creation_time   : 2019-12-10T13:01:51.000000Z
#   Duration: 00:05:41.37, start: 0.000000, bitrate: 1266 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], 39 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2019-12-10T13:01:51.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
# Output #0, mov, to '/Users/max/Documents/Insight/TwoStepper/classifier/movie_clips/turn.qxqu7p8oK5g__45__50.mov':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     encoder         : Lavf58.12.100
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 39 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 30k tbc (default)
#     Metadata:
#       creation_time   : 2019-12-10T13:01:51.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# frame=  220 fps=0.0 q=-1.0 Lsize=    1285kB time=00:00:04.98 bitrate=2112.6kbits/s speed=2.46e+03x
# video:1282kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.219784%
# ffmpeg version 4.0.2 Copyright (c) 2000-2018 the FFmpeg developers
#   built with Apple LLVM version 6.1.0 (clang-602.0.53) (based on LLVM 3.6.0svn)
#   configuration: --prefix=/anaconda3 --disable-doc --disable-openssl --enable-shared --enable-static --extra-cflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-cxxflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-libs='-lpthread -lm -lz' --enable-zlib --enable-pic --enable-pthreads --enable-gpl --enable-version3 --enable-hardcoded-tables --enable-avresample --enable-libfreetype --enable-gnutls --enable-libx264 --enable-libopenh264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'qxqu7p8oK5g.mp4':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     creation_time   : 2019-12-10T13:01:51.000000Z
#   Duration: 00:05:41.37, start: 0.000000, bitrate: 1266 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], 39 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2019-12-10T13:01:51.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
# Output #0, mov, to '/Users/max/Documents/Insight/TwoStepper/classifier/movie_clips/turn.qxqu7p8oK5g__42.5__48.75.mov':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     encoder         : Lavf58.12.100
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 39 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 30k tbc (default)
#     Metadata:
#       creation_time   : 2019-12-10T13:01:51.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# frame=  343 fps=0.0 q=-1.0 Lsize=    1880kB time=00:00:06.24 bitrate=2464.6kbits/s speed=1.88e+03x
# video:1876kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.208111%
# ffmpeg version 4.0.2 Copyright (c) 2000-2018 the FFmpeg developers
#   built with Apple LLVM version 6.1.0 (clang-602.0.53) (based on LLVM 3.6.0svn)
#   configuration: --prefix=/anaconda3 --disable-doc --disable-openssl --enable-shared --enable-static --extra-cflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-cxxflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-libs='-lpthread -lm -lz' --enable-zlib --enable-pic --enable-pthreads --enable-gpl --enable-version3 --enable-hardcoded-tables --enable-avresample --enable-libfreetype --enable-gnutls --enable-libx264 --enable-libopenh264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'qxqu7p8oK5g.mp4':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     creation_time   : 2019-12-10T13:01:51.000000Z
#   Duration: 00:05:41.37, start: 0.000000, bitrate: 1266 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], 39 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2019-12-10T13:01:51.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
# Output #0, mov, to '/Users/max/Documents/Insight/TwoStepper/classifier/movie_clips/turn.qxqu7p8oK5g__42.5__52.5.mov':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     encoder         : Lavf58.12.100
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 39 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 30k tbc (default)
#     Metadata:
#       creation_time   : 2019-12-10T13:01:51.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# frame=  455 fps=0.0 q=-1.0 Lsize=    2547kB time=00:00:09.98 bitrate=2089.6kbits/s speed=1.95e+03x
# video:2542kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.186140%
# ffmpeg version 4.0.2 Copyright (c) 2000-2018 the FFmpeg developers
#   built with Apple LLVM version 6.1.0 (clang-602.0.53) (based on LLVM 3.6.0svn)
#   configuration: --prefix=/anaconda3 --disable-doc --disable-openssl --enable-shared --enable-static --extra-cflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-cxxflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-libs='-lpthread -lm -lz' --enable-zlib --enable-pic --enable-pthreads --enable-gpl --enable-version3 --enable-hardcoded-tables --enable-avresample --enable-libfreetype --enable-gnutls --enable-libx264 --enable-libopenh264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'qxqu7p8oK5g.mp4':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     creation_time   : 2019-12-10T13:01:51.000000Z
#   Duration: 00:05:41.37, start: 0.000000, bitrate: 1266 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], 39 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2019-12-10T13:01:51.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
# Output #0, mov, to '/Users/max/Documents/Insight/TwoStepper/classifier/movie_clips/turn.qxqu7p8oK5g__46.25__52.5.mov':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     encoder         : Lavf58.12.100
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 39 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 30k tbc (default)
#     Metadata:
#       creation_time   : 2019-12-10T13:01:51.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# frame=  295 fps=0.0 q=-1.0 Lsize=    1746kB time=00:00:06.23 bitrate=2294.0kbits/s speed=2.31e+03x
# video:1743kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.192862%
# ffmpeg version 4.0.2 Copyright (c) 2000-2018 the FFmpeg developers
#   built with Apple LLVM version 6.1.0 (clang-602.0.53) (based on LLVM 3.6.0svn)
#   configuration: --prefix=/anaconda3 --disable-doc --disable-openssl --enable-shared --enable-static --extra-cflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-cxxflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-libs='-lpthread -lm -lz' --enable-zlib --enable-pic --enable-pthreads --enable-gpl --enable-version3 --enable-hardcoded-tables --enable-avresample --enable-libfreetype --enable-gnutls --enable-libx264 --enable-libopenh264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'qxqu7p8oK5g.mp4':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     creation_time   : 2019-12-10T13:01:51.000000Z
#   Duration: 00:05:41.37, start: 0.000000, bitrate: 1266 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], 39 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2019-12-10T13:01:51.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
# Output #0, mov, to '/Users/max/Documents/Insight/TwoStepper/classifier/movie_clips/turn.qxqu7p8oK5g__133__138.mov':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     encoder         : Lavf58.12.100
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 39 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 30k tbc (default)
#     Metadata:
#       creation_time   : 2019-12-10T13:01:51.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# frame=  297 fps=0.0 q=-1.0 Lsize=    1667kB time=00:00:04.97 bitrate=2746.4kbits/s speed=1.88e+03x
# video:1664kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.182803%
# ffmpeg version 4.0.2 Copyright (c) 2000-2018 the FFmpeg developers
#   built with Apple LLVM version 6.1.0 (clang-602.0.53) (based on LLVM 3.6.0svn)
#   configuration: --prefix=/anaconda3 --disable-doc --disable-openssl --enable-shared --enable-static --extra-cflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-cxxflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-libs='-lpthread -lm -lz' --enable-zlib --enable-pic --enable-pthreads --enable-gpl --enable-version3 --enable-hardcoded-tables --enable-avresample --enable-libfreetype --enable-gnutls --enable-libx264 --enable-libopenh264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'qxqu7p8oK5g.mp4':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     creation_time   : 2019-12-10T13:01:51.000000Z
#   Duration: 00:05:41.37, start: 0.000000, bitrate: 1266 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], 39 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2019-12-10T13:01:51.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
# Output #0, mov, to '/Users/max/Documents/Insight/TwoStepper/classifier/movie_clips/turn.qxqu7p8oK5g__130.5__136.75.mov':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     encoder         : Lavf58.12.100
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 39 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 30k tbc (default)
#     Metadata:
#       creation_time   : 2019-12-10T13:01:51.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# frame=  260 fps=0.0 q=-1.0 Lsize=    1485kB time=00:00:06.23 bitrate=1950.1kbits/s speed=2.91e+03x
# video:1482kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.185439%
# ffmpeg version 4.0.2 Copyright (c) 2000-2018 the FFmpeg developers
#   built with Apple LLVM version 6.1.0 (clang-602.0.53) (based on LLVM 3.6.0svn)
#   configuration: --prefix=/anaconda3 --disable-doc --disable-openssl --enable-shared --enable-static --extra-cflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-cxxflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-libs='-lpthread -lm -lz' --enable-zlib --enable-pic --enable-pthreads --enable-gpl --enable-version3 --enable-hardcoded-tables --enable-avresample --enable-libfreetype --enable-gnutls --enable-libx264 --enable-libopenh264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'qxqu7p8oK5g.mp4':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     creation_time   : 2019-12-10T13:01:51.000000Z
#   Duration: 00:05:41.37, start: 0.000000, bitrate: 1266 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], 39 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2019-12-10T13:01:51.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
# Output #0, mov, to '/Users/max/Documents/Insight/TwoStepper/classifier/movie_clips/turn.qxqu7p8oK5g__130.5__140.5.mov':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     encoder         : Lavf58.12.100
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 39 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 30k tbc (default)
#     Metadata:
#       creation_time   : 2019-12-10T13:01:51.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# frame=  372 fps=0.0 q=-1.0 Lsize=    2163kB time=00:00:09.97 bitrate=1776.5kbits/s speed=3.16e+03x
# video:2159kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.167246%
# ffmpeg version 4.0.2 Copyright (c) 2000-2018 the FFmpeg developers
#   built with Apple LLVM version 6.1.0 (clang-602.0.53) (based on LLVM 3.6.0svn)
#   configuration: --prefix=/anaconda3 --disable-doc --disable-openssl --enable-shared --enable-static --extra-cflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-cxxflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-libs='-lpthread -lm -lz' --enable-zlib --enable-pic --enable-pthreads --enable-gpl --enable-version3 --enable-hardcoded-tables --enable-avresample --enable-libfreetype --enable-gnutls --enable-libx264 --enable-libopenh264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'qxqu7p8oK5g.mp4':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     creation_time   : 2019-12-10T13:01:51.000000Z
#   Duration: 00:05:41.37, start: 0.000000, bitrate: 1266 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], 39 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2019-12-10T13:01:51.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
# Output #0, mov, to '/Users/max/Documents/Insight/TwoStepper/classifier/movie_clips/turn.qxqu7p8oK5g__134.25__140.5.mov':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     encoder         : Lavf58.12.100
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 39 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 30k tbc (default)
#     Metadata:
#       creation_time   : 2019-12-10T13:01:51.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# frame=  212 fps=0.0 q=-1.0 Lsize=    1342kB time=00:00:06.22 bitrate=1765.9kbits/s speed=2.61e+03x
# video:1339kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.182458%
# ffmpeg version 4.0.2 Copyright (c) 2000-2018 the FFmpeg developers
#   built with Apple LLVM version 6.1.0 (clang-602.0.53) (based on LLVM 3.6.0svn)
#   configuration: --prefix=/anaconda3 --disable-doc --disable-openssl --enable-shared --enable-static --extra-cflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-cxxflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-libs='-lpthread -lm -lz' --enable-zlib --enable-pic --enable-pthreads --enable-gpl --enable-version3 --enable-hardcoded-tables --enable-avresample --enable-libfreetype --enable-gnutls --enable-libx264 --enable-libopenh264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'qxqu7p8oK5g.mp4':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     creation_time   : 2019-12-10T13:01:51.000000Z
#   Duration: 00:05:41.37, start: 0.000000, bitrate: 1266 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], 39 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2019-12-10T13:01:51.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
# Output #0, mov, to '/Users/max/Documents/Insight/TwoStepper/classifier/movie_clips/turn.qxqu7p8oK5g__148__153.mov':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     encoder         : Lavf58.12.100
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 39 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 30k tbc (default)
#     Metadata:
#       creation_time   : 2019-12-10T13:01:51.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# frame=  267 fps=0.0 q=-1.0 Lsize=    1592kB time=00:00:04.98 bitrate=2616.1kbits/s speed=2.03e+03x
# video:1589kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.190359%
# ffmpeg version 4.0.2 Copyright (c) 2000-2018 the FFmpeg developers
#   built with Apple LLVM version 6.1.0 (clang-602.0.53) (based on LLVM 3.6.0svn)
#   configuration: --prefix=/anaconda3 --disable-doc --disable-openssl --enable-shared --enable-static --extra-cflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-cxxflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-libs='-lpthread -lm -lz' --enable-zlib --enable-pic --enable-pthreads --enable-gpl --enable-version3 --enable-hardcoded-tables --enable-avresample --enable-libfreetype --enable-gnutls --enable-libx264 --enable-libopenh264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'qxqu7p8oK5g.mp4':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     creation_time   : 2019-12-10T13:01:51.000000Z
#   Duration: 00:05:41.37, start: 0.000000, bitrate: 1266 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], 39 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2019-12-10T13:01:51.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
# Output #0, mov, to '/Users/max/Documents/Insight/TwoStepper/classifier/movie_clips/turn.qxqu7p8oK5g__145.5__151.75.mov':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     encoder         : Lavf58.12.100
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 39 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 30k tbc (default)
#     Metadata:
#       creation_time   : 2019-12-10T13:01:51.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# frame=  229 fps=0.0 q=-1.0 Lsize=    1323kB time=00:00:06.21 bitrate=1743.2kbits/s speed=2.51e+03x
# video:1320kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.203078%
# ffmpeg version 4.0.2 Copyright (c) 2000-2018 the FFmpeg developers
#   built with Apple LLVM version 6.1.0 (clang-602.0.53) (based on LLVM 3.6.0svn)
#   configuration: --prefix=/anaconda3 --disable-doc --disable-openssl --enable-shared --enable-static --extra-cflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-cxxflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-libs='-lpthread -lm -lz' --enable-zlib --enable-pic --enable-pthreads --enable-gpl --enable-version3 --enable-hardcoded-tables --enable-avresample --enable-libfreetype --enable-gnutls --enable-libx264 --enable-libopenh264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'qxqu7p8oK5g.mp4':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     creation_time   : 2019-12-10T13:01:51.000000Z
#   Duration: 00:05:41.37, start: 0.000000, bitrate: 1266 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], 39 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2019-12-10T13:01:51.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
# Output #0, mov, to '/Users/max/Documents/Insight/TwoStepper/classifier/movie_clips/turn.qxqu7p8oK5g__145.5__155.5.mov':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     encoder         : Lavf58.12.100
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 39 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 30k tbc (default)
#     Metadata:
#       creation_time   : 2019-12-10T13:01:51.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# frame=  342 fps=0.0 q=-1.0 Lsize=    2095kB time=00:00:09.98 bitrate=1717.9kbits/s speed=3.33e+03x
# video:2091kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.179062%
# ffmpeg version 4.0.2 Copyright (c) 2000-2018 the FFmpeg developers
#   built with Apple LLVM version 6.1.0 (clang-602.0.53) (based on LLVM 3.6.0svn)
#   configuration: --prefix=/anaconda3 --disable-doc --disable-openssl --enable-shared --enable-static --extra-cflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-cxxflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-libs='-lpthread -lm -lz' --enable-zlib --enable-pic --enable-pthreads --enable-gpl --enable-version3 --enable-hardcoded-tables --enable-avresample --enable-libfreetype --enable-gnutls --enable-libx264 --enable-libopenh264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'qxqu7p8oK5g.mp4':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     creation_time   : 2019-12-10T13:01:51.000000Z
#   Duration: 00:05:41.37, start: 0.000000, bitrate: 1266 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], 39 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2019-12-10T13:01:51.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
# Output #0, mov, to '/Users/max/Documents/Insight/TwoStepper/classifier/movie_clips/turn.qxqu7p8oK5g__149.25__155.5.mov':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     encoder         : Lavf58.12.100
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 39 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 30k tbc (default)
#     Metadata:
#       creation_time   : 2019-12-10T13:01:51.000000Z
# ...
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '4-2MHaNny8g.mp4':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     creation_time   : 2018-10-26T04:38:59.000000Z
#   Duration: 00:29:38.38, start: 0.000000, bitrate: 1138 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 1 kb/s, 29.97 fps, 29.97 tbr, 90k tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2018-10-26T04:38:59.000000Z
#       handler_name    : VideoHandler
# Output #0, mov, to '/Users/max/Documents/Insight/TwoStepper/classifier/movie_clips/shadow.4-2MHaNny8g__1012.5__1018.75.mov':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     encoder         : Lavf58.12.100
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 1 kb/s, 29.97 fps, 29.97 tbr, 90k tbn, 90k tbc (default)
#     Metadata:
#       creation_time   : 2018-10-26T04:38:59.000000Z
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# frame=  325 fps=0.0 q=-1.0 Lsize=    2208kB time=00:00:06.21 bitrate=2909.4kbits/s speed=2.22e+03x
# video:2204kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.192123%
# ffmpeg version 4.0.2 Copyright (c) 2000-2018 the FFmpeg developers
#   built with Apple LLVM version 6.1.0 (clang-602.0.53) (based on LLVM 3.6.0svn)
#   configuration: --prefix=/anaconda3 --disable-doc --disable-openssl --enable-shared --enable-static --extra-cflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-cxxflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-libs='-lpthread -lm -lz' --enable-zlib --enable-pic --enable-pthreads --enable-gpl --enable-version3 --enable-hardcoded-tables --enable-avresample --enable-libfreetype --enable-gnutls --enable-libx264 --enable-libopenh264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '4-2MHaNny8g.mp4':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     creation_time   : 2018-10-26T04:38:59.000000Z
#   Duration: 00:29:38.38, start: 0.000000, bitrate: 1138 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 1 kb/s, 29.97 fps, 29.97 tbr, 90k tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2018-10-26T04:38:59.000000Z
#       handler_name    : VideoHandler
# Output #0, mov, to '/Users/max/Documents/Insight/TwoStepper/classifier/movie_clips/shadow.4-2MHaNny8g__1012.5__1022.5.mov':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     encoder         : Lavf58.12.100
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 1 kb/s, 29.97 fps, 29.97 tbr, 90k tbn, 90k tbc (default)
#     Metadata:
#       creation_time   : 2018-10-26T04:38:59.000000Z
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# frame=  438 fps=0.0 q=-1.0 Lsize=    2672kB time=00:00:09.98 bitrate=2191.4kbits/s speed=2.76e+03x
# video:2666kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.203189%
# ffmpeg version 4.0.2 Copyright (c) 2000-2018 the FFmpeg developers
#   built with Apple LLVM version 6.1.0 (clang-602.0.53) (based on LLVM 3.6.0svn)
#   configuration: --prefix=/anaconda3 --disable-doc --disable-openssl --enable-shared --enable-static --extra-cflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-cxxflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-libs='-lpthread -lm -lz' --enable-zlib --enable-pic --enable-pthreads --enable-gpl --enable-version3 --enable-hardcoded-tables --enable-avresample --enable-libfreetype --enable-gnutls --enable-libx264 --enable-libopenh264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '4-2MHaNny8g.mp4':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     creation_time   : 2018-10-26T04:38:59.000000Z
#   Duration: 00:29:38.38, start: 0.000000, bitrate: 1138 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 1 kb/s, 29.97 fps, 29.97 tbr, 90k tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2018-10-26T04:38:59.000000Z
#       handler_name    : VideoHandler
# Output #0, mov, to '/Users/max/Documents/Insight/TwoStepper/classifier/movie_clips/shadow.4-2MHaNny8g__1016.25__1022.5.mov':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     encoder         : Lavf58.12.100
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 1 kb/s, 29.97 fps, 29.97 tbr, 90k tbn, 90k tbc (default)
#     Metadata:
#       creation_time   : 2018-10-26T04:38:59.000000Z
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# frame=  278 fps=0.0 q=-1.0 Lsize=    1506kB time=00:00:06.23 bitrate=1977.6kbits/s speed=2.75e+03x
# video:1502kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.248073%
# ffmpeg version 4.0.2 Copyright (c) 2000-2018 the FFmpeg developers
#   built with Apple LLVM version 6.1.0 (clang-602.0.53) (based on LLVM 3.6.0svn)
#   configuration: --prefix=/anaconda3 --disable-doc --disable-openssl --enable-shared --enable-static --extra-cflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-cxxflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-libs='-lpthread -lm -lz' --enable-zlib --enable-pic --enable-pthreads --enable-gpl --enable-version3 --enable-hardcoded-tables --enable-avresample --enable-libfreetype --enable-gnutls --enable-libx264 --enable-libopenh264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '4-2MHaNny8g.mp4':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     creation_time   : 2018-10-26T04:38:59.000000Z
#   Duration: 00:29:38.38, start: 0.000000, bitrate: 1138 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 1 kb/s, 29.97 fps, 29.97 tbr, 90k tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2018-10-26T04:38:59.000000Z
#       handler_name    : VideoHandler
# Output #0, mov, to '/Users/max/Documents/Insight/TwoStepper/classifier/movie_clips/shadow.4-2MHaNny8g__1076__1079.mov':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     encoder         : Lavf58.12.100
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 1 kb/s, 29.97 fps, 29.97 tbr, 90k tbn, 90k tbc (default)
#     Metadata:
#       creation_time   : 2018-10-26T04:38:59.000000Z
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# frame=  211 fps=0.0 q=-1.0 Lsize=    1568kB time=00:00:02.97 bitrate=4314.7kbits/s speed=1.42e+03x
# video:1565kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.191885%
# ffmpeg version 4.0.2 Copyright (c) 2000-2018 the FFmpeg developers
#   built with Apple LLVM version 6.1.0 (clang-602.0.53) (based on LLVM 3.6.0svn)
#   configuration: --prefix=/anaconda3 --disable-doc --disable-openssl --enable-shared --enable-static --extra-cflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-cxxflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-libs='-lpthread -lm -lz' --enable-zlib --enable-pic --enable-pthreads --enable-gpl --enable-version3 --enable-hardcoded-tables --enable-avresample --enable-libfreetype --enable-gnutls --enable-libx264 --enable-libopenh264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '4-2MHaNny8g.mp4':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     creation_time   : 2018-10-26T04:38:59.000000Z
#   Duration: 00:29:38.38, start: 0.000000, bitrate: 1138 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 1 kb/s, 29.97 fps, 29.97 tbr, 90k tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2018-10-26T04:38:59.000000Z
#       handler_name    : VideoHandler
# Output #0, mov, to '/Users/max/Documents/Insight/TwoStepper/classifier/movie_clips/shadow.4-2MHaNny8g__1074.5__1078.25.mov':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     encoder         : Lavf58.12.100
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 1 kb/s, 29.97 fps, 29.97 tbr, 90k tbn, 90k tbc (default)
#     Metadata:
#       creation_time   : 2018-10-26T04:38:59.000000Z
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# frame=  189 fps=0.0 q=-1.0 Lsize=    1418kB time=00:00:03.74 bitrate=3102.5kbits/s speed=1.85e+03x
# video:1415kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.195710%
# ffmpeg version 4.0.2 Copyright (c) 2000-2018 the FFmpeg developers
#   built with Apple LLVM version 6.1.0 (clang-602.0.53) (based on LLVM 3.6.0svn)
#   configuration: --prefix=/anaconda3 --disable-doc --disable-openssl --enable-shared --enable-static --extra-cflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-cxxflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-libs='-lpthread -lm -lz' --enable-zlib --enable-pic --enable-pthreads --enable-gpl --enable-version3 --enable-hardcoded-tables --enable-avresample --enable-libfreetype --enable-gnutls --enable-libx264 --enable-libopenh264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '4-2MHaNny8g.mp4':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     creation_time   : 2018-10-26T04:38:59.000000Z
#   Duration: 00:29:38.38, start: 0.000000, bitrate: 1138 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 1 kb/s, 29.97 fps, 29.97 tbr, 90k tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2018-10-26T04:38:59.000000Z
#       handler_name    : VideoHandler
# Output #0, mov, to '/Users/max/Documents/Insight/TwoStepper/classifier/movie_clips/shadow.4-2MHaNny8g__1074.5__1080.5.mov':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     encoder         : Lavf58.12.100
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 1 kb/s, 29.97 fps, 29.97 tbr, 90k tbn, 90k tbc (default)
#     Metadata:
#       creation_time   : 2018-10-26T04:38:59.000000Z
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# frame=  256 fps=0.0 q=-1.0 Lsize=    1931kB time=00:00:05.97 bitrate=2646.1kbits/s speed=2.46e+03x
# video:1928kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.181952%
# ffmpeg version 4.0.2 Copyright (c) 2000-2018 the FFmpeg developers
#   built with Apple LLVM version 6.1.0 (clang-602.0.53) (based on LLVM 3.6.0svn)
#   configuration: --prefix=/anaconda3 --disable-doc --disable-openssl --enable-shared --enable-static --extra-cflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-cxxflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-libs='-lpthread -lm -lz' --enable-zlib --enable-pic --enable-pthreads --enable-gpl --enable-version3 --enable-hardcoded-tables --enable-avresample --enable-libfreetype --enable-gnutls --enable-libx264 --enable-libopenh264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '4-2MHaNny8g.mp4':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     creation_time   : 2018-10-26T04:38:59.000000Z
#   Duration: 00:29:38.38, start: 0.000000, bitrate: 1138 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 1 kb/s, 29.97 fps, 29.97 tbr, 90k tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2018-10-26T04:38:59.000000Z
#       handler_name    : VideoHandler
# Output #0, mov, to '/Users/max/Documents/Insight/TwoStepper/classifier/movie_clips/shadow.4-2MHaNny8g__1076.75__1080.5.mov':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     encoder         : Lavf58.12.100
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 1 kb/s, 29.97 fps, 29.97 tbr, 90k tbn, 90k tbc (default)
#     Metadata:
#       creation_time   : 2018-10-26T04:38:59.000000Z
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# frame=  256 fps=0.0 q=-1.0 Lsize=    1931kB time=00:00:03.72 bitrate=4242.5kbits/s speed=1.53e+03x
# video:1928kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.181952%
